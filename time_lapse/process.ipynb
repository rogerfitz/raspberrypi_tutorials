# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os

# %%
PHOTO_DIR="/home/pi/Desktop/photos/bonchi/"
photos=os.listdir(PHOTO_DIR)
photo_df=pd.DataFrame(photos,columns=["fname"])

# %%
len(photos)
# Out:
# 4513

# %%
def show_image(image):
    #this downsamples the image but shows it easily in our notebook
    w = 16
    h = 9
    fig = plt.figure(frameon=False)
    fig.set_size_inches(w,h)
    #plt.imshow()#, aspect='auto',figsize = (10,10))
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    ax.imshow(image, aspect='auto')
def read_image(fname):
    return cv2.imread(PHOTO_DIR+fname)
img=read_image(photo_df.iloc[0]['fname'])
show_image(img)

# %%
img=read_image(photo_df.iloc[100]['fname'])
show_image(img)

# %%
# !rm output.avi

# %%
import datetime

# %%
photo_df['time']=photo_df['fname'].apply(lambda x: datetime.datetime.strptime(x,"pic_%Y%m%d-%H:%M.jpg"))

# %%
photo_df=photo_df.sort_values(by="time")
show=photo_df.iloc[34:]
show
# Out:
#                        fname                time
# 821   pic_20181213-07:00.jpg 2018-12-13 07:00:00
# 2297  pic_20181213-07:15.jpg 2018-12-13 07:15:00
# 868   pic_20181213-07:30.jpg 2018-12-13 07:30:00
# 1873  pic_20181213-07:45.jpg 2018-12-13 07:45:00
# 2279  pic_20181213-08:00.jpg 2018-12-13 08:00:00
# 566   pic_20181213-08:15.jpg 2018-12-13 08:15:00
# 2835  pic_20181213-08:30.jpg 2018-12-13 08:30:00
# 1431  pic_20181213-08:45.jpg 2018-12-13 08:45:00
# 315   pic_20181213-09:00.jpg 2018-12-13 09:00:00
# 3505  pic_20181213-09:15.jpg 2018-12-13 09:15:00
# 2114  pic_20181213-09:30.jpg 2018-12-13 09:30:00
# 2968  pic_20181213-09:45.jpg 2018-12-13 09:45:00
# 3942  pic_20181213-10:00.jpg 2018-12-13 10:00:00
# 4163  pic_20181213-10:15.jpg 2018-12-13 10:15:00
# 2839  pic_20181213-10:30.jpg 2018-12-13 10:30:00
# 3904  pic_20181213-10:45.jpg 2018-12-13 10:45:00
# 2245  pic_20181213-11:00.jpg 2018-12-13 11:00:00
# 842   pic_20181213-11:15.jpg 2018-12-13 11:15:00
# ...

# %%
show_image(read_image(show.iloc[i]['fname']))

# %%
# !rm output.mp4

# %%
fourcc = cv2.VideoWriter_fourcc(*'H264') # install ffmpeg
img_np = np.array(img)
y,x,channels=np.shape(img_np)
out = cv2.VideoWriter("output.mp4", fourcc, 20.0, (x, y))
# cv2.namedWindow('Screen', cv2.WND_PROP_FULLSCREEN)  
# cv2.setWindowProperty("Screen",cv2.WND_PROP_FULLSCREEN,cv2.WINDOW_FULLSCREEN)
#cv2.moveWindow("Screen",-x,0)
i=0
while i<=1000:
    # capture computer screen
    img = read_image(show.iloc[i]['fname'])
    # convert image to numpy array
    img_np = np.array(img)
    # convert color space from BGR to RGB
    frame = cv2.cvtColor(img_np, cv2.COLOR_BGR2RGB)
    print(np.shape(frame))
    # show image on OpenCV frame
    #cv2.imshow("Screen", frame)
    i+=1
    # write frame to video writer
    for j in range(5):
        out.write(frame)
out.release()
# Out:
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# (720, 1280, 3)
# ...

# %%
#todo add video in notebook support with cv2
